# %% [markdown]
# # 1 - The Model

# %% [markdown]
# **1.1** Before anything we need to import our data that was previously treated, we import it in a pickle file, after that we normalize all the pixels dividing every pixel by the maximum value of 255.

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt


pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

y = np.array(y)
print("Before normalization")
print(X[0])
X = X/255.0 #normalize the array of images

print("After")
print(X[0])

print(len(X),len(y))
# Out:
# Before normalization
# [[123  87 133 ... 159 178 192]
#  [112 106 130 ... 192 171 193]
#  [104 114 131 ... 204 178 185]
#  ...
#  [144 141 145 ... 137 130 108]
#  [145 155 159 ...  92  80  61]
#  [152 149 150 ...  74 155  68]]
# After
# [[0.48235294 0.34117647 0.52156863 ... 0.62352941 0.69803922 0.75294118]
#  [0.43921569 0.41568627 0.50980392 ... 0.75294118 0.67058824 0.75686275]
#  [0.40784314 0.44705882 0.51372549 ... 0.8        0.69803922 0.7254902 ]
#  ...
#  [0.56470588 0.55294118 0.56862745 ... 0.5372549  0.50980392 0.42352941]
#  [0.56862745 0.60784314 0.62352941 ... 0.36078431 0.31372549 0.23921569]
#  [0.59607843 0.58431373 0.58823529 ... 0.29019608 0.60784314 0.26666667]]
# 19963 19963

# %% [markdown]
# **1.2** On this section we work with our first model, we developed a inchoate model only to see how a rudimentary model will perform with an image dataset. As we can see bellow, this simples model barely cross the 50% precision line.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation

model = Sequential()

model.add (Dense (64,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(1,activation = 'sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

#fisrt_model = model.fit(X,y,batch_size=1, epochs=1, validation_split=0.1)
# after 5 epochs plateau

# %%
fisrt_model = model.fit(X,y,batch_size=1, epochs=1, validation_split=0.1)
# Out:
# 17966/17966 [==============================] - 76s 4ms/step - loss: 0.6932 - accuracy: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.4967

# %% [markdown]
# **1.3** Let's see how our rudementary model will peform after each epoch.

# %%
history = model.fit(X,y,batch_size=16, epochs=5, validation_split=0.2)

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/5
# 999/999 [==============================] - 8s 8ms/step - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6932 - val_accuracy: 0.4926
# Epoch 2/5
# 999/999 [==============================] - 7s 7ms/step - loss: 0.6932 - accuracy: 0.4943 - val_loss: 0.6932 - val_accuracy: 0.4926
# Epoch 3/5
# 999/999 [==============================] - 7s 7ms/step - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6931 - val_accuracy: 0.5074
# Epoch 4/5
# 999/999 [==============================] - 7s 7ms/step - loss: 0.6932 - accuracy: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5074
# Epoch 5/5
# 999/999 [==============================] - 7s 7ms/step - loss: 0.6932 - accuracy: 0.5002 - val_loss: 0.6932 - val_accuracy: 0.4926
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # 2 - Improving the Model

# %% [markdown]
# **2.1** What if we overboost our model?

# %% [markdown]
# Let's configure the capacity of layer and nodes, let's change our batch size, and set a loss function that was already been proven to be the best one for a binary classification problem and add activation functions on every layer, to see how it will perform?

# %%
modelnew = Sequential()

modelnew.add (Dense (320,activation='relu',kernel_initializer='he_uniform'))

modelnew.add (Dense (320,activation='relu',kernel_initializer='he_uniform'))

modelnew.add (Dense (320,activation='relu',kernel_initializer='he_uniform'))

modelnew.add(Dense(1,activation = 'sigmoid'))

modelnew.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = modelnew.fit(X,y,batch_size=64, epochs=20, validation_split=0.1)

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/20
# 281/281 [==============================] - 53s 186ms/step - loss: 0.6994 - accuracy: 0.5365 - val_loss: 0.6847 - val_accuracy: 0.5577
# Epoch 2/20
# 281/281 [==============================] - 66s 234ms/step - loss: 0.6845 - accuracy: 0.5549 - val_loss: 0.6796 - val_accuracy: 0.5726
# Epoch 3/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6798 - accuracy: 0.5684 - val_loss: 0.6774 - val_accuracy: 0.5790
# Epoch 4/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6798 - accuracy: 0.5685 - val_loss: 0.6786 - val_accuracy: 0.5706
# Epoch 5/20
# 281/281 [==============================] - 52s 187ms/step - loss: 0.6770 - accuracy: 0.5738 - val_loss: 0.6759 - val_accuracy: 0.5813
# Epoch 6/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6769 - accuracy: 0.5746 - val_loss: 0.6764 - val_accuracy: 0.5708
# Epoch 7/20
# 281/281 [==============================] - 53s 187ms/step - loss: 0.6753 - accuracy: 0.5767 - val_loss: 0.6742 - val_accuracy: 0.5874
# Epoch 8/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6727 - accuracy: 0.5830 - val_loss: 0.6744 - val_accuracy: 0.5834
# Epoch 9/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6723 - accuracy: 0.5829 - val_loss: 0.6773 - val_accuracy: 0.5763
# Epoch 10/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6726 - accuracy: 0.5821 - val_loss: 0.6719 - val_accuracy: 0.5891
# Epoch 11/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6710 - accuracy: 0.5837 - val_loss: 0.6718 - val_accuracy: 0.5866
# Epoch 12/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6686 - accuracy: 0.5896 - val_loss: 0.6750 - val_accuracy: 0.5775
# Epoch 13/20
# 281/281 [==============================] - 53s 187ms/step - loss: 0.6688 - accuracy: 0.5904 - val_loss: 0.6747 - val_accuracy: 0.5784
# Epoch 14/20
# 281/281 [==============================] - 52s 187ms/step - loss: 0.6686 - accuracy: 0.5881 - val_loss: 0.6762 - val_accuracy: 0.5817
# Epoch 15/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6663 - accuracy: 0.5918 - val_loss: 0.6707 - val_accuracy: 0.5874
# Epoch 16/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6628 - accuracy: 0.5973 - val_loss: 0.6727 - val_accuracy: 0.5829
# Epoch 17/20
# 281/281 [==============================] - 53s 187ms/step - loss: 0.6621 - accuracy: 0.5976 - val_loss: 0.6729 - val_accuracy: 0.5821
# Epoch 18/20
# 281/281 [==============================] - 52s 187ms/step - loss: 0.6636 - accuracy: 0.5958 - val_loss: 0.6897 - val_accuracy: 0.5665
# Epoch 19/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6653 - accuracy: 0.5916 - val_loss: 0.6703 - val_accuracy: 0.5895
# Epoch 20/20
# 281/281 [==============================] - 52s 186ms/step - loss: 0.6593 - accuracy: 0.6016 - val_loss: 0.6745 - val_accuracy: 0.5898

# %% [markdown]
# We can see that our results improved in a good margin, but is our model good or is it just overfitting?

# %% [markdown]
# # 3 - Better Generalization

# %% [markdown]
# **3.1** Let's implement a Dropout with 10% of chance to happen, to see how our model will work with this technique, also we decrease the amount of nodes in each layer.

# %%
modelnew = Sequential()

modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform'))
modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform'))
modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform'))
modelnew.add(Dropout(0.1))
modelnew.add(Dense(1,activation = 'sigmoid'))

modelnew.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = modelnew.fit(X,y,batch_size=32, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 562/562 [==============================] - 12s 20ms/step - loss: 0.6978 - accuracy: 0.5248 - val_loss: 0.6871 - val_accuracy: 0.5528
# Epoch 2/5
# 562/562 [==============================] - 11s 19ms/step - loss: 0.6880 - accuracy: 0.5451 - val_loss: 0.6847 - val_accuracy: 0.5583
# Epoch 3/5
# 562/562 [==============================] - 12s 21ms/step - loss: 0.6849 - accuracy: 0.5547 - val_loss: 0.6815 - val_accuracy: 0.5633
# Epoch 4/5
# 562/562 [==============================] - 11s 19ms/step - loss: 0.6838 - accuracy: 0.5591 - val_loss: 0.6818 - val_accuracy: 0.5626
# Epoch 5/5
# 562/562 [==============================] - 11s 19ms/step - loss: 0.6832 - accuracy: 0.5600 - val_loss: 0.6807 - val_accuracy: 0.5724

# %%
# import norm
from keras.constraints import max_norm
# instantiate norm
norm = max_norm(3.0)

# %% [markdown]
# **3.2** Forgetting the dropout for a moment let's try setting weights constraits to our model.

# %%
modelnew = Sequential()

modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
#modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
#modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
#modelnew.add(Dropout(0.1))
modelnew.add(Dense(1,activation = 'sigmoid'))

modelnew.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = modelnew.fit(X,y,batch_size=32, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 562/562 [==============================] - 10s 16ms/step - loss: 0.6965 - accuracy: 0.5264 - val_loss: 0.6868 - val_accuracy: 0.5492
# Epoch 2/10
# 562/562 [==============================] - 8s 14ms/step - loss: 0.6851 - accuracy: 0.5558 - val_loss: 0.6849 - val_accuracy: 0.5591
# Epoch 3/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6851 - accuracy: 0.5509 - val_loss: 0.6822 - val_accuracy: 0.5634
# Epoch 4/10
# 562/562 [==============================] - 7s 13ms/step - loss: 0.6825 - accuracy: 0.5614 - val_loss: 0.6811 - val_accuracy: 0.5678
# Epoch 5/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6830 - accuracy: 0.5601 - val_loss: 0.6836 - val_accuracy: 0.5634
# Epoch 6/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6808 - accuracy: 0.5653 - val_loss: 0.6839 - val_accuracy: 0.5591
# Epoch 7/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6808 - accuracy: 0.5652 - val_loss: 0.6871 - val_accuracy: 0.5466
# Epoch 8/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6804 - accuracy: 0.5654 - val_loss: 0.6795 - val_accuracy: 0.5722
# Epoch 9/10
# 562/562 [==============================] - 8s 14ms/step - loss: 0.6786 - accuracy: 0.5710 - val_loss: 0.6783 - val_accuracy: 0.5682
# Epoch 10/10
# 562/562 [==============================] - 8s 13ms/step - loss: 0.6785 - accuracy: 0.5720 - val_loss: 0.6775 - val_accuracy: 0.5748

# %% [markdown]
# **3.3** The junction of both tecniques above will be implemented in our final model.

# %%
modelnew = Sequential()

modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
modelnew.add(Dropout(0.1))
modelnew.add (Dense (64,activation='relu',kernel_initializer='he_uniform',kernel_constraint=max_norm(3), bias_constraint=max_norm(3)))
modelnew.add(Dropout(0.1))
modelnew.add(Dense(1,activation = 'sigmoid'))

modelnew.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

history = modelnew.fit(X,y,batch_size=32, epochs=100, validation_split=0.1)
# Out:
# Epoch 1/100
# 562/562 [==============================] - 17s 28ms/step - loss: 0.6940 - accuracy: 0.5192 - val_loss: 0.6862 - val_accuracy: 0.5516
# Epoch 2/100
# 562/562 [==============================] - 14s 25ms/step - loss: 0.6894 - accuracy: 0.5369 - val_loss: 0.6849 - val_accuracy: 0.5562
# Epoch 3/100
# 562/562 [==============================] - 14s 24ms/step - loss: 0.6842 - accuracy: 0.5571 - val_loss: 0.6822 - val_accuracy: 0.5630
# Epoch 4/100
# 562/562 [==============================] - 13s 24ms/step - loss: 0.6847 - accuracy: 0.5564 - val_loss: 0.6811 - val_accuracy: 0.5689
# Epoch 5/100
# 562/562 [==============================] - 14s 25ms/step - loss: 0.6834 - accuracy: 0.5569 - val_loss: 0.6806 - val_accuracy: 0.5638
# Epoch 6/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6841 - accuracy: 0.5570 - val_loss: 0.6817 - val_accuracy: 0.5631
# Epoch 7/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6817 - accuracy: 0.5633 - val_loss: 0.6820 - val_accuracy: 0.5577
# Epoch 8/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6809 - accuracy: 0.5647 - val_loss: 0.6802 - val_accuracy: 0.5657
# Epoch 9/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6808 - accuracy: 0.5645 - val_loss: 0.6779 - val_accuracy: 0.5717
# Epoch 10/100
# 562/562 [==============================] - 17s 31ms/step - loss: 0.6786 - accuracy: 0.5705 - val_loss: 0.6864 - val_accuracy: 0.5615
# Epoch 11/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6796 - accuracy: 0.5697 - val_loss: 0.6752 - val_accuracy: 0.5812
# Epoch 12/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6788 - accuracy: 0.5706 - val_loss: 0.6748 - val_accuracy: 0.5823
# Epoch 13/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6772 - accuracy: 0.5740 - val_loss: 0.6774 - val_accuracy: 0.5736
# Epoch 14/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6755 - accuracy: 0.5774 - val_loss: 0.6753 - val_accuracy: 0.5795
# Epoch 15/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6761 - accuracy: 0.5753 - val_loss: 0.6747 - val_accuracy: 0.5802
# Epoch 16/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6766 - accuracy: 0.5742 - val_loss: 0.6746 - val_accuracy: 0.5861
# Epoch 17/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6760 - accuracy: 0.5753 - val_loss: 0.6751 - val_accuracy: 0.5778
# Epoch 18/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6749 - accuracy: 0.5784 - val_loss: 0.6728 - val_accuracy: 0.5860
# Epoch 19/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6747 - accuracy: 0.5784 - val_loss: 0.6733 - val_accuracy: 0.5843
# Epoch 20/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6753 - accuracy: 0.5777 - val_loss: 0.6755 - val_accuracy: 0.5809
# Epoch 21/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6765 - accuracy: 0.5737 - val_loss: 0.6728 - val_accuracy: 0.5856
# Epoch 22/100
# 562/562 [==============================] - 15s 27ms/step - loss: 0.6749 - accuracy: 0.5782 - val_loss: 0.6724 - val_accuracy: 0.5835
# Epoch 23/100
# 562/562 [==============================] - 15s 27ms/step - loss: 0.6725 - accuracy: 0.5817 - val_loss: 0.6798 - val_accuracy: 0.5565
# Epoch 24/100
# 562/562 [==============================] - 15s 27ms/step - loss: 0.6738 - accuracy: 0.5788 - val_loss: 0.6712 - val_accuracy: 0.5872
# Epoch 25/100
# 562/562 [==============================] - 15s 27ms/step - loss: 0.6737 - accuracy: 0.5791 - val_loss: 0.6711 - val_accuracy: 0.5873
# Epoch 26/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6731 - accuracy: 0.5800 - val_loss: 0.6739 - val_accuracy: 0.5842
# Epoch 27/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6719 - accuracy: 0.5836 - val_loss: 0.6732 - val_accuracy: 0.5829
# Epoch 28/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6729 - accuracy: 0.5809 - val_loss: 0.6741 - val_accuracy: 0.5789
# Epoch 29/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6706 - accuracy: 0.5850 - val_loss: 0.6730 - val_accuracy: 0.5813
# Epoch 30/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6748 - accuracy: 0.5783 - val_loss: 0.6714 - val_accuracy: 0.5870
# Epoch 31/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6728 - accuracy: 0.5801 - val_loss: 0.6750 - val_accuracy: 0.5782
# Epoch 32/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6717 - accuracy: 0.5831 - val_loss: 0.6739 - val_accuracy: 0.5824
# Epoch 33/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6717 - accuracy: 0.5837 - val_loss: 0.6722 - val_accuracy: 0.5856
# Epoch 34/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6729 - accuracy: 0.5808 - val_loss: 0.6720 - val_accuracy: 0.5867
# Epoch 35/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6720 - accuracy: 0.5821 - val_loss: 0.6725 - val_accuracy: 0.5869
# Epoch 36/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6703 - accuracy: 0.5863 - val_loss: 0.6705 - val_accuracy: 0.5901
# Epoch 37/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6712 - accuracy: 0.5844 - val_loss: 0.6722 - val_accuracy: 0.5893
# Epoch 38/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6713 - accuracy: 0.5847 - val_loss: 0.6721 - val_accuracy: 0.5847
# Epoch 39/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6691 - accuracy: 0.5880 - val_loss: 0.6721 - val_accuracy: 0.5865
# Epoch 40/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6703 - accuracy: 0.5858 - val_loss: 0.6709 - val_accuracy: 0.5893
# Epoch 41/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6677 - accuracy: 0.5905 - val_loss: 0.6710 - val_accuracy: 0.5893
# Epoch 42/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6698 - accuracy: 0.5868 - val_loss: 0.6708 - val_accuracy: 0.5891
# Epoch 43/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6702 - accuracy: 0.5859 - val_loss: 0.6735 - val_accuracy: 0.5825
# Epoch 44/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6692 - accuracy: 0.5880 - val_loss: 0.6716 - val_accuracy: 0.5862
# Epoch 45/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6677 - accuracy: 0.5900 - val_loss: 0.6711 - val_accuracy: 0.5882
# Epoch 46/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6691 - accuracy: 0.5880 - val_loss: 0.6712 - val_accuracy: 0.5892
# Epoch 47/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6708 - accuracy: 0.5857 - val_loss: 0.6705 - val_accuracy: 0.5897
# Epoch 48/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6708 - accuracy: 0.5853 - val_loss: 0.6715 - val_accuracy: 0.5865
# Epoch 49/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6688 - accuracy: 0.5869 - val_loss: 0.6692 - val_accuracy: 0.5913
# Epoch 50/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6694 - accuracy: 0.5865 - val_loss: 0.6699 - val_accuracy: 0.5895
# Epoch 51/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6682 - accuracy: 0.5890 - val_loss: 0.6707 - val_accuracy: 0.5885
# Epoch 52/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6690 - accuracy: 0.5879 - val_loss: 0.6706 - val_accuracy: 0.5884
# Epoch 53/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6689 - accuracy: 0.5886 - val_loss: 0.6689 - val_accuracy: 0.5926
# Epoch 54/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6676 - accuracy: 0.5899 - val_loss: 0.6710 - val_accuracy: 0.5861
# Epoch 55/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6689 - accuracy: 0.5881 - val_loss: 0.6703 - val_accuracy: 0.5896
# Epoch 56/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6680 - accuracy: 0.5893 - val_loss: 0.6704 - val_accuracy: 0.5886
# Epoch 57/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6672 - accuracy: 0.5911 - val_loss: 0.6702 - val_accuracy: 0.5915
# Epoch 58/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6679 - accuracy: 0.5899 - val_loss: 0.6694 - val_accuracy: 0.5912
# Epoch 59/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6678 - accuracy: 0.5882 - val_loss: 0.6705 - val_accuracy: 0.5874
# Epoch 60/100
# 562/562 [==============================] - 17s 31ms/step - loss: 0.6675 - accuracy: 0.5906 - val_loss: 0.6695 - val_accuracy: 0.5919
# Epoch 61/100
# 562/562 [==============================] - 17s 31ms/step - loss: 0.6688 - accuracy: 0.5869 - val_loss: 0.6685 - val_accuracy: 0.5935
# Epoch 62/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6663 - accuracy: 0.5929 - val_loss: 0.6719 - val_accuracy: 0.5867
# Epoch 63/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6679 - accuracy: 0.5909 - val_loss: 0.6712 - val_accuracy: 0.5872
# Epoch 64/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6674 - accuracy: 0.5900 - val_loss: 0.6724 - val_accuracy: 0.5806
# Epoch 65/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6682 - accuracy: 0.5886 - val_loss: 0.6699 - val_accuracy: 0.5908
# Epoch 66/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6668 - accuracy: 0.5907 - val_loss: 0.6716 - val_accuracy: 0.5869
# Epoch 67/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6660 - accuracy: 0.5930 - val_loss: 0.6684 - val_accuracy: 0.5932
# Epoch 68/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6658 - accuracy: 0.5922 - val_loss: 0.6690 - val_accuracy: 0.5916
# Epoch 69/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6659 - accuracy: 0.5916 - val_loss: 0.6691 - val_accuracy: 0.5936
# Epoch 70/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6669 - accuracy: 0.5912 - val_loss: 0.6717 - val_accuracy: 0.5861
# Epoch 71/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6661 - accuracy: 0.5915 - val_loss: 0.6698 - val_accuracy: 0.5921
# Epoch 72/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6663 - accuracy: 0.5913 - val_loss: 0.6696 - val_accuracy: 0.5918
# Epoch 73/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6663 - accuracy: 0.5923 - val_loss: 0.6690 - val_accuracy: 0.5921
# Epoch 74/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6654 - accuracy: 0.5940 - val_loss: 0.6732 - val_accuracy: 0.5821
# Epoch 75/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6663 - accuracy: 0.5917 - val_loss: 0.6702 - val_accuracy: 0.5893
# Epoch 76/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6641 - accuracy: 0.5954 - val_loss: 0.6700 - val_accuracy: 0.5899
# Epoch 77/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6664 - accuracy: 0.5911 - val_loss: 0.6710 - val_accuracy: 0.5900
# Epoch 78/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6660 - accuracy: 0.5926 - val_loss: 0.6699 - val_accuracy: 0.5914
# Epoch 79/100
# 562/562 [==============================] - 16s 28ms/step - loss: 0.6660 - accuracy: 0.5927 - val_loss: 0.6699 - val_accuracy: 0.5914
# Epoch 80/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6652 - accuracy: 0.5939 - val_loss: 0.6724 - val_accuracy: 0.5864
# Epoch 81/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6648 - accuracy: 0.5934 - val_loss: 0.6726 - val_accuracy: 0.5848
# Epoch 82/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6649 - accuracy: 0.5949 - val_loss: 0.6697 - val_accuracy: 0.5896
# Epoch 83/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6650 - accuracy: 0.5944 - val_loss: 0.6704 - val_accuracy: 0.5909
# Epoch 84/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6642 - accuracy: 0.5954 - val_loss: 0.6684 - val_accuracy: 0.5931
# Epoch 85/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6659 - accuracy: 0.5931 - val_loss: 0.6691 - val_accuracy: 0.5919
# Epoch 86/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6666 - accuracy: 0.5912 - val_loss: 0.6712 - val_accuracy: 0.5881
# Epoch 87/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6650 - accuracy: 0.5936 - val_loss: 0.6719 - val_accuracy: 0.5868
# Epoch 88/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6661 - accuracy: 0.5920 - val_loss: 0.6712 - val_accuracy: 0.5874
# Epoch 89/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6640 - accuracy: 0.5951 - val_loss: 0.6698 - val_accuracy: 0.5901
# Epoch 90/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6646 - accuracy: 0.5949 - val_loss: 0.6712 - val_accuracy: 0.5882
# Epoch 91/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6649 - accuracy: 0.5948 - val_loss: 0.6711 - val_accuracy: 0.5875
# Epoch 92/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6645 - accuracy: 0.5947 - val_loss: 0.6687 - val_accuracy: 0.5933
# Epoch 93/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6641 - accuracy: 0.5966 - val_loss: 0.6688 - val_accuracy: 0.5937
# Epoch 94/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6641 - accuracy: 0.5956 - val_loss: 0.6698 - val_accuracy: 0.5916
# Epoch 95/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6640 - accuracy: 0.5960 - val_loss: 0.6699 - val_accuracy: 0.5919
# Epoch 96/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6662 - accuracy: 0.5921 - val_loss: 0.6742 - val_accuracy: 0.5801
# Epoch 97/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6638 - accuracy: 0.5952 - val_loss: 0.6724 - val_accuracy: 0.5827
# Epoch 98/100
# 562/562 [==============================] - 17s 30ms/step - loss: 0.6637 - accuracy: 0.5959 - val_loss: 0.6708 - val_accuracy: 0.5878
# Epoch 99/100
# 562/562 [==============================] - 17s 29ms/step - loss: 0.6645 - accuracy: 0.5955 - val_loss: 0.6708 - val_accuracy: 0.5894
# Epoch 100/100
# 562/562 [==============================] - 16s 29ms/step - loss: 0.6629 - accuracy: 0.5977 - val_loss: 0.6711 - val_accuracy: 0.5891

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # 4 - Results

# %% [markdown]
# **4.1** We saw that at the beginning that our model when was implemented in a poorly way, the results barely pass the line of 50%. After testing and experimenting new methods to our model we achived a val_loss: 0.6711 and val_accuracy: 0.5891.

# %% [markdown]
# That is not the ideal but, we are working with images without implementing a convolutional neural network (CNN), so at the beginning of this project i was aiming in a acurracy of 60%.

# %% [markdown]
# We did not reach our goal, but we got pretty close, so, i'm satisfied with the implementation of our model without CNN to predict if the image show a Cat or a Dog.
